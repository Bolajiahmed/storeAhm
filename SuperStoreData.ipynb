# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\\Users\\44789\\Downloads\\superstore_data.csv")

# %%
df.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3  11/05/2014        0        10  ...                0                 0
# 4  08/04/2014        0         6  ...               11                 0
#
# ...

# %%
df.tail(5)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1  07/03/2013       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0  03/12/2012       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2  01/09/2012       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# dtype: int64

# %%
df['Income'].fillna(0,inplace=True)

# %%
null=df[df['Income']==0]

# %%
null
# Out:
#          Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 134    8996        1957         PhD        Married     0.0        2         1
# 262    1994        1983  Graduation        Married     0.0        1         0
# 394    3769        1972         PhD       Together     0.0        1         0
# 449    5255        1986  Graduation         Single     0.0        1         0
# 525    8268        1961         PhD        Married     0.0        0         1
# 590   10629        1973    2n Cycle        Married     0.0        1         0
# 899   10475        1970      Master       Together     0.0        0         1
# 997    9235        1957  Graduation         Single     0.0        1         1
# 1096   4345        1964    2n Cycle         Single     0.0        1         1
# 1185   7187        1969      Master       Together     0.0        1         1
# 1213   8720        1978    2n Cycle       Together     0.0        0         0
# ...

# %%
df['Income'].mean()
# Out:
# 51687.459375

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Income'])
plt.title(f'Histogram of Customer Income')
plt.show()

# %%
MaritalStatus=df['Marital_Status'].value_counts()

# %%
MaritalStatus
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
MaritalStatus.plot.pie(autopct='%1.1f%%')
plt.title(f'Pie Chart of Customer Marital Status')
plt.ylabel('')
plt.show()

# %%
PivotTable=df.pivot_table(index='Marital_Status',columns='Education', values='Income',aggfunc='sum',fill_value=0)

# %%
PivotTable
# Out:
# Education        2n Cycle     Basic  Graduation     Master         PhD
# Marital_Status
# Absurd                0.0       0.0     79244.0    65487.0         0.0
# Alone                 0.0       0.0     34176.0    61331.0     35860.0
# Divorced        1136088.0    9548.0   6488599.0  1862282.0   2761024.0
# Married         3696088.0  439210.0  21793311.0  7353472.0  11046226.0
# Single          1932262.0  328296.0  12625257.0  4014792.0   5118203.0
# Together        2505239.0  297361.0  15891167.0  5315119.0   6500805.0
# Widow            256961.0   22123.0   1924183.0   642417.0   1446914.0
# YOLO                  0.0       0.0         0.0        0.0     96864.0

# %%
PivotTable.max()
# Out:
# Education
# 2n Cycle       3696088.0
# Basic           439210.0
# Graduation    21793311.0
# Master         7353472.0
# PhD           11046226.0
# dtype: float64

# %%
correlationMatrix=df.select_dtypes(include=['Float64','int64']).corr()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(correlationMatrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
